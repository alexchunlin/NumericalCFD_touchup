# %% [markdown]
# <a href="https://colab.research.google.com/github/alexchunlin/NumericalCFD_touchup/blob/main/notebooks/level_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Level 2 Maze Challenge

# %%
# Start from a clean state
# %cd /content
# !rm -rf efr-maze-challenge || true
# !git clone --depth 1 https://github.com/Every-Flavor-Robotics/efr-maze-challenge.git
# %cd efr-maze-challenge

# Install requirements
# !pip install -r requirements.txt

# Add repo to Python path and reload to avoid Colab caching
import sys
import importlib
sys.path.insert(0, "/content/efr-maze-challenge")

import maze_challenge
importlib.reload(maze_challenge)

from typing import Dict, List, Set, Tuple

# Get the reverse of a direction for backtracking
REVERSE_DIRECTION = {
    "N": "S",
    "S": "N",
    "E": "W",
    "W": "E",
}
# Out:
# /content
# Cloning into 'efr-maze-challenge'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 19 (delta 2), reused 9 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 15.15 KiB | 397.00 KiB/s, done.
# Resolving deltas: 100% (2/2), done.
# /content/efr-maze-challenge
# Requirement already satisfied: click==8.2.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 3)) (8.2.1)
# Collecting labyrinth-py==1.0.4 (from -r requirements.txt (line 5))
#   Downloading labyrinth_py-1.0.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 7)) (4.67.1)
# Downloading labyrinth_py-1.0.4-py3-none-any.whl (27 kB)
# Installing collected packages: labyrinth-py
# Successfully installed labyrinth-py-1.0.4

# %%
# You can import any additional modules here that you might need
import random

class MySolver(maze_challenge.Solver):
    """
    🚀 Your Maze Solver

    This is the main class you'll modify to solve the maze challenge.

    Inherit from `Solver` and implement your maze-solving logic in the `choose_move` method.
    The goal is to navigate from the starting point to the goal using only local information.

    You are given:
      - The current position (row, col) of the agent
      - A dictionary of possible moves: Dict[str, Tuple[int, int]]
        where the keys are directions ("NORTH", "SOUTH", "EAST", "WEST")
        and the values are the coordinates of neighboring cells

    You must:
      - Return one of the available direction keys as a string on each call to `choose_move`

    """

    def __init__(self, width: int, height: int):
        """
        Initialize your solver. You can store any internal state here.

        Args:
            width (int): width of the maze
            height (int): height of the maze
        """
        super().__init__(width, height)

        # You can add any variables your solver might need here
        # Variables you define here can be accessed anywhere in the class

        # For example, here's a list that can be used to store which grid cells
        #    have been visited.
        self.visited = []

    def choose_move(
        self,
        position: Tuple[int, int],
        cherry_position: Tuple[int, int],
        possible_moves: Dict[str, Tuple[int, int]],
    ) -> str:
        """
        Decide the next move given the current position and available directions.

        Args:
            position (Tuple[int, int]): Your current (row, col) in the maze
            possible_moves (Dict[str, Tuple[int, int]]): Valid directions and the
                coordinates they would lead to, e.g. {"N": (3, 2), "E": (4, 3)}

        Returns:
            str: One of the keys in `possible_moves`, e.g. "N", "S", etc.
        """

        # You can do anything with the variables you defined above here, and
        #    they will save between calls of this function.

        # For example, to add the current cell to the list of visited cells,
        #    you can do the following.
        self.visited.append(position)

        # You need to return one of the possible moves, which is the one
        #    that will be executed
        # Here, we are choosing a random move to return
        random_move = random.choice(list(possible_moves.keys()))

        return random_move

# %%
maze_challenge.run_solver(MySolver, fast=False)
# Out:
# Streaming output truncated to the last 5000 lines.
#                             🔸 Visited Cells: 31 / 400
#                             📦 Total Moves: 335
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🤖   🔸   🔸                |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3920
#                             🤖 Robot Position: (3, 1)
#                             🔸 Visited Cells: 31 / 400
#                             📦 Total Moves: 336
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🤖   🔸                |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 4010
#                             🤖 Robot Position: (3, 2)
#                             🔸 Visited Cells: 31 / 400
#                             📦 Total Moves: 337
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🤖                |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 4100
#                             🤖 Robot Position: (3, 3)
#                             🔸 Visited Cells: 31 / 400
#                             📦 Total Moves: 338
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🔸   🤖           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 4190
#                             🤖 Robot Position: (3, 4)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 339
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🤖   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 4080
#                             🤖 Robot Position: (3, 3)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 340
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🤖   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3970
#                             🤖 Robot Position: (3, 2)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 341
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🤖   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3860
#                             🤖 Robot Position: (3, 1)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 342
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🤖   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3750
#                             🤖 Robot Position: (2, 1)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 343
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🤖   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3840
#                             🤖 Robot Position: (3, 1)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 344
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🤖   🔸   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 3730
#                             🤖 Robot Position: (3, 0)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 345
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
# ...
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 2900
#                             🤖 Robot Position: (1, 1)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 418
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🤖 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 2990
#                             🤖 Robot Position: (1, 2)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 419
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🤖   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🔸 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 2880
#                             🤖 Robot Position: (0, 2)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 420
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸   🔸 |    |                   |                   |    |              |         |    |
# +    +----+    +    +    +    +----+----+----+    +----+----+----+    +    +----+    +    +----+    +
# | 🔸   🔸   🤖 | 🔸 |                                            |              |                   |
# +----+----+    +----+----+----+----+    +----+    +----+    +----+    +----+    +----+    +----+    +
# | 🔸 | 🔸   🔸   🔸   🔸 |         |    |    |    |              |         |    |    |         |    |
# +    +    +----+----+----+----+    +    +    +----+    +----+    +----+----+----+    +    +    +----+
# | 🔸   🔸   🔸   🔸   🔸           |    |         |         |    |              |         |    |    |
# +    +----+----+----+----+----+    +----+    +    +    +----+    +----+----+    +    +    +----+    +
# | 🔸   🔸   🔸 | 🔸   🔸 |              |    |              |    |              |    |              |
# +----+----+    +----+    +    +----+----+----+    +----+----+----+----+----+    +----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸 |    |         |              |    |    |                             |    |
# +----+    +----+----+----+----+----+    +----+    +    +    +    +    +    +----+----+----+    +    +
# | 🔸   🔸 |    |         |    |         |         |    |         |    |         |                   |
# +    +----+    +    +----+    +----+    +    +----+    +    +----+----+    +----+    +----+    +----+
# | 🔸   🔸      |         |    |                   |    |    |         |    |         |         |    |
# +    +----+----+    +    +    +    +----+----+----+    +    +    +----+----+    +----+    +----+    +
# |                   |    |         |              |                   |    |         |    |    |    |
# +    +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +    +----+    +    +
# |              |              |         |              |         |         |    |    |              |
# +----+    +----+----+    +----+    +----+----+----+----+    +    +    +    +----+    +----+    +    +
# |    |         |              |         |                   |    |    |    |    |         |    |    |
# +    +    +----+    +----+----+----+----+----+    +----+    +----+----+    +    +----+    +    +----+
# |         |    |              |                   |    | 🍒 |    |         |    |                   |
# +----+----+    +----+    +----+----+----+----+    +    +----+    +    +----+    +    +    +    +    +
# |    |                        |    |                        |    |         |         |    |    |    |
# +    +    +----+    +    +----+    +----+    +----+    +    +    +----+----+----+    +----+----+    +
# |         |    |    |    |                   |         |    |    |              |              |    |
# +    +    +    +    +----+----+    +----+    +----+----+    +    +----+----+    +----+    +----+----+
# |    |    |    |         |         |         |         |         |    |                             |
# +    +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +    +----+    +
# |    |         |    |         |    |    |                   |                   |    |    |    |    |
# +----+    +----+    +    +    +    +----+----+    +    +----+----+----+----+    +----+----+    +----+
# |    |         |         |    |    |              |         |         |                             |
# +    +----+    +----+----+    +    +    +    +    +----+    +----+    +    +    +    +----+----+    +
# |         |                   |         |    |    |         |              |    |    |    |         |
# +    +----+----+    +----+    +----+    +    +----+----+    +----+    +----+----+----+    +    +    +
# |                        |         |    |    |         |    |         |         |              |    |
# +    +    +----+----+    +    +    +----+    +----+    +----+----+----+----+    +----+    +----+----+
# |    |    |              |    |         |                   |                                    🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 2970
#                             🤖 Robot Position: (1, 2)
#                             🔸 Visited Cells: 32 / 400
#                             📦 Total Moves: 421
#                             🍒 Cherry Captured: No
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (11, 11)
#                             🏆 End:   (19, 19)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-5-4108452488.py in <cell line: 0>()
# ----> 1 maze_challenge.run_solver(MySolver, fast=False)
#
# /content/efr-maze-challenge/maze_challenge/runners.py in run_solver(solver_class, fast)
#      59             break
#      60
# ---> 61         time.sleep(sleep)
#      62
#      63     maze_interface.print_final_stats()
#
# KeyboardInterrupt:

# %%
maze_challenge.run_solver(DFSSolver, fast=True)
# Out:
# Streaming output truncated to the last 5000 lines.
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🤖   🔸 |    |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸           |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5110
#                             🤖 Robot Position: (6, 17)
#                             🔸 Visited Cells: 259 / 400
#                             📦 Total Moves: 453
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 |    |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🤖           |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5200
#                             🤖 Robot Position: (7, 17)
#                             🔸 Visited Cells: 259 / 400
#                             📦 Total Moves: 454
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 |    |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🤖      |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5290
#                             🤖 Robot Position: (7, 18)
#                             🔸 Visited Cells: 260 / 400
#                             📦 Total Moves: 455
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 |    |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🤖 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5380
#                             🤖 Robot Position: (7, 19)
#                             🔸 Visited Cells: 261 / 400
#                             📦 Total Moves: 456
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🤖 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5270
#                             🤖 Robot Position: (6, 19)
#                             🔸 Visited Cells: 262 / 400
#                             📦 Total Moves: 457
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🤖 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5360
#                             🤖 Robot Position: (7, 19)
#                             🔸 Visited Cells: 262 / 400
#                             📦 Total Moves: 458
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🤖   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 |    |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5250
#                             🤖 Robot Position: (7, 18)
#                             🔸 Visited Cells: 262 / 400
#                             📦 Total Moves: 459
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🤖 |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5340
#                             🤖 Robot Position: (8, 18)
#                             🔸 Visited Cells: 263 / 400
#                             📦 Total Moves: 460
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🤖   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🔸 |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5230
#                             🤖 Robot Position: (7, 18)
#                             🔸 Visited Cells: 263 / 400
#                             📦 Total Moves: 461
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🤖   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🔸 |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    |    |         |         |    |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           |              |         |    |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              |              |    |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              |              |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5120
#                             🤖 Robot Position: (7, 17)
#                             🔸 Visited Cells: 263 / 400
#                             📦 Total Moves: 462
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🤖 | 🔸 |    |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 |         |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 |    |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸           |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸           |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸      |         |    |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 |         |         |    |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# ...
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           | 🔸   🔸   🔸 | 🔸   🔸 | 🤖 |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              | 🔸   🔸   🔸 | 🔸 |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              | 🔸   🔸   🔸 |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5490
#                             🤖 Robot Position: (16, 19)
#                             🔸 Visited Cells: 300 / 400
#                             📦 Total Moves: 535
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸 |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              | 🔸   🔸   🔸 | 🤖 |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              | 🔸   🔸   🔸 |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5580
#                             🤖 Robot Position: (17, 19)
#                             🔸 Visited Cells: 300 / 400
#                             📦 Total Moves: 536
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸 |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              | 🔸   🔸   🔸 | 🔸 |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              | 🔸   🔸   🤖 |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🏆 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5670
#                             🤖 Robot Position: (18, 19)
#                             🔸 Visited Cells: 300 / 400
#                             📦 Total Moves: 537
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
# move(): Goal reached!
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
# | 🏁   🔸 | 🔸 | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸 |         |    | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸 |
# +----+    +    +    +    +    +----+    +----+----+    +    +    +    +    +    +----+----+----+    +
# | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 |    |         | 🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 |
# +----+    +----+----+----+----+----+    +    +    +----+    +----+----+----+    +----+----+----+    +
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 | 🔸   🔸 |              | 🔸   🔸   🔸   🔸   🔸 | 🔸 |
# +    +    +    +    +----+    +    +----+----+----+    +----+    +----+    +    +----+    +----+----+
# | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸   🔸   🔸 |         | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+----+    +    +----+    +----+----+----+----+----+    +----+----+    +----+    +    +
# | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸 | 🔸 |                   |              | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+    +    +    +----+    +    +----+----+----+    +----+    +    +----+    +    +----+    +----+
# | 🔸   🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 |         |    |    | 🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 |
# +----+----+    +    +    +    +----+    +----+----+    +----+----+    +    +    +    +----+    +----+
# | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    | 🔸 |         |                   | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+    +    +----+----+    +    +----+    +----+----+    +    +    +----+    +----+    +----+    +
# | 🔸   🔸 | 🔸 |         | 🔸 |                             |    |    | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +    +----+    +----+----+    +    +----+----+----+----+    +----+----+    +    +    +----+
# | 🔸 | 🔸   🔸                          |    | 🔸   🔸   🔸 | 🔸 |              | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+    +----+    +----+----+    +----+----+----+    +----+    +----+----+----+----+    +----+    +
# | 🔸   🔸   🔸 |         |    |         | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸 |
# +    +    +    +----+----+    +    +----+    +    +    +----+----+----+    +    +----+    +----+    +
# | 🔸 |    | 🔸 |         |         | 🔸   🔸 | 🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸 | 🔸 | 🔸 | 🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +----+    +    +    +    +    +
# | 🔸 | 🔸   🔸 |              |    | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸   🔸 |
# +    +    +----+----+----+----+----+----+    +    +    +----+    +----+    +----+----+    +----+----+
# | 🔸   🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 |
# +    +    +----+----+----+    +----+    +----+----+----+----+----+----+    +    +----+    +----+----+
# | 🔸 |         | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+    +    +----+    +    +    +----+----+----+    +----+    +    +----+----+    +----+    +
# | 🔸 | 🔸 |    | 🔸 | 🔸   🔸 | 🔸 | 🔸 | 🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +    +----+    +----+    +    +----+----+----+----+    +----+----+    +    +----+----+    +    +
# | 🔸   🔸   🔸   🔸 |    | 🔸   🔸   🔸 | 🔸 | 🔸 | 🔸   🔸 |    |    | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸 |
# +----+----+----+    +    +----+    +----+    +    +----+    +    +    +    +----+    +----+----+    +
# | 🔸   🔸 | 🔸   🔸 |    | 🔸   🔸      | 🔸   🔸   🔸   🔸           | 🔸   🔸   🔸 | 🔸   🔸 | 🔸 |
# +    +----+    +----+    +    +----+    +    +----+----+    +----+----+    +----+    +----+    +    +
# | 🔸   🔸 | 🔸   🔸   🔸   🔸      |    | 🔸      |              |              | 🔸   🔸   🔸 | 🔸 |
# +----+    +----+    +----+----+----+----+    +----+----+    +----+    +----+    +----+----+    +    +
# | 🔸   🔸   🔸   🔸   🔸 | 🔸   🔸   🔸 | 🔸 |              |    |    |              | 🔸   🔸   🔸 |
# +    +    +    +----+    +    +    +----+    +----+----+----+    +    +----+----+----+----+    +    +
# | 🔸 | 🔸 | 🔸   🔸 | 🔸   🔸 | 🔸   🔸   🔸                |                   |              | 🤖 |
# +----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+----+
#
#                             🧭  Maze Stats
#                             ──────────────
#                             🎯 Current Score: 5770
#                             🤖 Robot Position: (19, 19)
#                             🔸 Visited Cells: 301 / 400
#                             📦 Total Moves: 537
#                             🍒 Cherry Captured: Yes
#
#
#                             📋  Maze Info
#                             ──────────────
#                             📐 Size: 20 x 20
#                             🏁 Start: (0, 0)
#                             🍒 Cherry: (5, 6)
#                             🏆 End:   (19, 19)
#
#
#                             ━━━━━━━━━━━━━━━━━━━━━━━
#                             🏁  Final Maze Summary
#                             ━━━━━━━━━━━━━━━━━━━━━━━
#                             🗺️  Cells Visited:     301 / 400
#                             🕹️  Moves Taken:       537 moves
#                             📏 Shortest Path:      62 moves
#                             🍒 Cherry Captured:    ✅ Yes!
#                             🏆 Goal Reached:       ✅ Yes!
#
#                             ━━━━━━━━━━━━━━━━━━━━━━━
#                             🎯 Efficiency Score:   5770
#                             🧭 Explorer Score:     2473
#                             ━━━━━━━━━━━━━━━━━━━━━━━

# %%
maze_challenge.evaluate_solver(MySolver)
# Out:
# 🏁 Running Maze Solver for 5000 mazes...
# Running Samples: 100%|██████████| 5000/5000 [03:14<00:00, 25.71sample/s]
# 📊 Average Stats Over 5000 Runs
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Visited cells            : 103.26
# Num moves                : 1988.80
# Goal reached             : 0.02
# Cherry captured          : 0.25
# Score                    : -11553.97
# Explorer score           : -956.17
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 🕒  Completed in 194.96 seconds
